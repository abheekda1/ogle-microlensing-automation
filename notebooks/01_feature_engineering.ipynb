# %% [markdown]
# # 1. Imports and Environment Setup
# - Load required scientific Python libraries and local modules
# - Configure plotting style for consistent visuals
# - Add project root to `sys.path` for module imports

# %%
import pandas as pd
import os
import sys
import glob
from src.feature_extraction import extract_simple_features
from tqdm import tqdm
import matplotlib.pyplot as plt
from src.preprocessing import preprocess_lc

sys.path.append(os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Define some style info for plots

# %%
plt.style.use('default')
plt.rcParams["figure.figsize"] = (12, 8)
plt.set_cmap('magma')

# %% [markdown]
# # 2. Load an Example Photometry File
# - Read a single `.dat` photometry file
# - Inspect column structure and formatting
# - Perform a quick sanity check on the raw data

# %%
df = pd.read_csv("data/raw/ogle4/2025/photometry/blg-0001_phot.dat",
                 sep='\\s+', names=["HJD", "mag", "err", 'unk1', 'unk2'])
df.head()
# Out:
#             HJD     mag    err  unk1   unk2
# 0  2.457822e+06  20.079  0.223  4.66   83.0
# 1  2.457823e+06  20.084  0.261  4.73  120.0
# 2  2.457827e+06  19.480  0.175  5.08  144.0
# 3  2.457828e+06  19.932  0.235  5.55  103.0
# 4  2.457829e+06  19.921  0.182  4.17  104.0

# %% [markdown]
# # 3. Load and Combine All Photometry Files
# - Iterate through all photometry files in the dataset
# - Extract event identifiers from filenames
# - Concatenate all light curves into one DataFrame
# - Save the combined dataset as a compressed parquet file

# %%
records = []
for path in glob.glob("data/raw/ogle4/2025/photometry/*.dat"):
    event = os.path.basename(path).split("_")[0]
    df = pd.read_csv(path, sep='\\s+', names=["HJD", "mag", "err", "seeing", "bg"])
    df["event"] = event
    records.append(df)

all_df = pd.concat(records, ignore_index=True)
all_df.to_parquet("data/processed/ogle2025_lightcurves.parquet", compression="snappy", engine="fastparquet")
print("Saved", len(all_df), "rows.")
# Out:
# Saved 2565579 rows.

# %% [markdown]
# # 5. Feature Extraction for Each Event
# - Preprocess individual light curves
# - Compute simple features for each event
# - Aggregate features into a DataFrame and save to disk

# %%
features = []
for event in tqdm(all_df["event"].unique(), desc="Extracting features"):
    df_event = all_df[all_df["event"] == event]
    df_event = preprocess_lc(df_event)
    feats = extract_simple_features(df_event["t_rel"].values, df_event["flux"].values, df_event["err"].values, seeing=df_event["seeing"].values, bg=df_event["bg"].values)
    feats["event"] = event
    features.append(feats)

features_df = pd.DataFrame(features).fillna(0)
features_df.to_csv("data/features/features_ogle2025_simple.csv", index=False)
# Out:
# Extracting features: 100%|██████████| 1496/1496 [01:30<00:00, 16.60it/s]
