# %%
import pandas as pd
import os
import sys
import glob
import numpy as np

sys.path.append(os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Test 1 CSV

# %%
df = pd.read_csv("data/raw/ogle4/2025/photometry/blg-0001_phot.dat",
                 sep='\\s+', names=["HJD", "mag", "err", 'unk1', 'unk2'])
df.head()
# Out:
#             HJD     mag    err  unk1   unk2
# 0  2.457822e+06  20.079  0.223  4.66   83.0
# 1  2.457823e+06  20.084  0.261  4.73  120.0
# 2  2.457827e+06  19.480  0.175  5.08  144.0
# 3  2.457828e+06  19.932  0.235  5.55  103.0
# 4  2.457829e+06  19.921  0.182  4.17  104.0

# %%
records = []
for path in glob.glob("data/raw/ogle4/2025/photometry/*.dat"):
    event = os.path.basename(path).split("_")[0]
    df = pd.read_csv(path, sep='\\s+', names=["HJD", "mag", "err", "seeing", "bg"])
    df["event"] = event
    records.append(df)

all_df = pd.concat(records, ignore_index=True)
all_df.to_parquet("data/processed/ogle2025_lightcurves.parquet", compression="snappy", engine="fastparquet")
print("Saved", len(all_df), "rows.")
# Out:
# Saved 2565579 rows.

# %%
def preprocess_lc(df):
    df = df.sort_values("HJD").dropna()
    baseline = np.median(df["mag"].nlargest(int(len(df)*0.3)))
    df["flux"] = 10**(-0.4 * (df["mag"] - baseline))
    df["t_rel"] = df["HJD"] - df["HJD"].min()
    return df

# %%
from src.feature_extraction import extract_simple_features, extract_features
from tqdm import tqdm

features_simple = []
features = []
for event in tqdm(all_df["event"].unique(), desc="Extracting features"):
    df_event = all_df[all_df["event"] == event]
    df_event = preprocess_lc(df_event)
    feats = extract_simple_features(df_event["t_rel"].values, df_event["flux"].values, df_event["err"].values, seeing=df_event["seeing"].values, bg=df_event["bg"].values)
    # feats = extract_features(df_event["t_rel"].values, df_event["flux"].values, df_event["err"].values)
    feats["event"] = event
    # feats["event"] = event
    features.append(feats)
    # features.append(feats)

features_df = pd.DataFrame(features).fillna(0)
features_df.to_csv("data/features/features_ogle2025_simple.csv", index=False)
# features_df = pd.DataFrame(features).fillna(0)
# features_df.to_csv("data/features/features_ogle2025.csv", index=False)
# Out:
# Extracting features: 100%|█| 1496/1496 [0

# %%
features_df = pd.read_csv("data/features/features_ogle2025_simple.csv")
features_df.head()
# Out:
#    n_points    duration  cadence_med  cadence_std  cadence_iqr  cadence_min  \
# 0      4569  3178.62416     0.048045    13.452426     0.063340      0.00213
# 1      2466  3174.66809     0.060230    18.426902     0.814770      0.00786
# 2      4315  3177.66444     0.048150    13.858576     0.090477      0.00464
# 3      2387  3174.66809     0.061825    18.742690     0.823135      0.00786
# 4       318  3160.66304     1.956380    92.993883     1.977550      0.07517
#
#    cadence_max  cadence_max_gap  cadence_frac_large_gaps  flux_mean  ...  \
# 0    872.77257        872.77257                 0.240368   1.077983  ...
# 1    873.67026        873.67026                 0.368357   1.170225  ...
# 2    872.77213        872.77213                 0.247102   1.275117  ...
# 3    873.67026        873.67026                 0.375524   1.117995  ...
# 4   1618.25929       1618.25929                 0.132492   1.133161  ...
#
#    stetson_j  seeing_mean  seeing_std  seeing_flux_corr  seeing_flux_slope  \
# 0   0.045913     5.584277    0.934971         -0.042871          -0.003921
# 1   0.130544     5.274822    0.978471          0.042904           0.008202
# 2   0.448160     5.450058    0.945527          0.070996           0.023373
# 3   0.724446     5.274474    0.982689          0.093014           0.031831
# 4   0.701419     5.853522    0.934506          0.079003           0.045375
#
#       bg_mean      bg_std  bg_flux_corr  bg_flux_slope     event
# 0  578.365288  180.502229      0.034468       0.000016  blg-0491
# 1  411.100973  182.343757      0.055667       0.000057  blg-0801
# 2  532.940209  165.865294      0.065899       0.000124  blg-0490
# 3  412.123167  183.794338      0.002544       0.000005  blg-0800
# 4  413.415094  212.409338     -0.043535      -0.000110  blg-0239
#
# [5 rows x 60 columns]

# %%
from sklearn.preprocessing import StandardScaler

X = features_df.drop(columns=["event"], errors="ignore").fillna(0)
X_scaled = StandardScaler().fit_transform(X)

# %%
import umap

umap_model = umap.UMAP(
    n_neighbors=30,      # local neighborhood size
    min_dist=0.2,        # controls cluster tightness
    n_components=2,      # 2D embedding
    metric="euclidean",
    random_state=42
)

embedding = umap_model.fit_transform(X_scaled)
features_df["umap_x"] = embedding[:, 0]
features_df["umap_y"] = embedding[:, 1]

embedding
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/a356/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# array([[-25.526321,  34.209637],
#        [-25.409752,  35.32297 ],
#        [-25.96815 ,  35.86292 ],
#        ...,
#        [-28.11898 ,  36.375725],
#        [-25.602663,  33.96016 ],
#        [-26.493572,  36.05118 ]], shape=(1496, 2), dtype=float32)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(
    features_df["umap_x"], features_df["umap_y"],
    s=10, alpha=0.7, c="gray"
)
plt.title("UMAP embedding (unclustered)")
plt.xlabel("UMAP 1")
plt.ylabel("UMAP 2")
plt.show()

# %%
features_df.head()
for col in ["flux_skew", "fwhm_time", "duration"]:
    plt.figure(figsize=(7,5))
    plt.scatter(
        features_df["umap_x"], features_df["umap_y"],
        c=features_df[col], cmap="viridis", s=15
    )
    plt.title(f"UMAP colored by {col}")
    plt.xlabel("UMAP 1"); plt.ylabel("UMAP 2")
    plt.colorbar(label=col)
    plt.show()

# %%
features_df.iloc[:, :-1]
# Out:
#       n_points    duration  cadence_med  cadence_std  cadence_iqr  \
# 0         4569  3178.62416     0.048045    13.452426     0.063340
# 1         2466  3174.66809     0.060230    18.426902     0.814770
# 2         4315  3177.66444     0.048150    13.858576     0.090477
# 3         2387  3174.66809     0.061825    18.742690     0.823135
# 4          318  3160.66304     1.956380    92.993883     1.977550
# ...        ...         ...          ...          ...          ...
# 1491      4250  3178.62717     0.048990    13.928394     0.611930
# 1492      3984  3178.62717     0.049980    14.463652     0.625035
# 1493      4547  3177.66442     0.047925    13.497520     0.069725
# 1494      4544  3178.62735     0.047980    13.493140     0.064070
# 1495      4146  3177.66444     0.049570    14.176442     0.615300
#
#       cadence_min  cadence_max  cadence_max_gap  cadence_frac_large_gaps  \
# 0         0.00213    872.77257        872.77257                 0.240368
# 1         0.00786    873.67026        873.67026                 0.368357
# 2         0.00464    872.77213        872.77213                 0.247102
# 3         0.00786    873.67026        873.67026                 0.375524
# 4         0.07517   1618.25929       1618.25929                 0.132492
# ...           ...          ...              ...                      ...
# 1491      0.00145    872.77258        872.77258                 0.261709
# 1492      0.00145    872.80925        872.80925                 0.263620
# 1493      0.00094    872.77216        872.77216                 0.241971
# 1494      0.00177    871.77393        871.77393                 0.239930
# 1495      0.00265    872.77213        872.77213                 0.258384
#
#       flux_mean  ...  seeing_mean  seeing_std  seeing_flux_corr  \
# 0      1.077983  ...     5.584277    0.934971         -0.042871
# 1      1.170225  ...     5.274822    0.978471          0.042904
# 2      1.275117  ...     5.450058    0.945527          0.070996
# 3      1.117995  ...     5.274474    0.982689          0.093014
# 4      1.133161  ...     5.853522    0.934506          0.079003
# ...         ...  ...          ...         ...               ...
# 1491   1.173951  ...     5.482395    0.982404         -0.060430
# 1492   1.316572  ...     5.186152    0.898601          0.229819
# 1493   1.188923  ...     5.402028    0.997293         -0.064926
# 1494   1.069662  ...     5.500180    0.984070         -0.142241
# 1495   1.253357  ...     5.314383    0.904178         -0.039667
#
#       seeing_flux_slope     bg_mean      bg_std  bg_flux_corr  bg_flux_slope  \
# 0             -0.003921  578.365288  180.502229      0.034468       0.000016
# 1              0.008202  411.100973  182.343757      0.055667       0.000057
# 2              0.023373  532.940209  165.865294      0.065899       0.000124
# 3              0.031831  412.123167  183.794338      0.002544       0.000005
# 4              0.045375  413.415094  212.409338     -0.043535      -0.000110
# ...                 ...         ...         ...           ...            ...
# 1491          -0.016661  600.904471  191.351779      0.015738       0.000022
# 1492           0.115378  561.745984  170.148040      0.257006       0.000681
# 1493          -0.019645  538.329448  192.089416     -0.024077      -0.000038
# 1494          -0.011214  600.233055  181.937521     -0.099953      -0.000043
# 1495          -0.011233  539.194645  165.563755      0.132185       0.000204
#
#          event     umap_x
# 0     blg-0491 -25.526321
# 1     blg-0801 -25.409752
# 2     blg-0490 -25.968149
# 3     blg-0800 -29.220160
# 4     blg-0239 -31.654470
# ...        ...        ...
# 1491  blg-0649 -28.215578
# 1492  blg-1228 -26.474440
# 1493  blg-0286 -28.118980
# 1494  blg-1229 -25.602663
# 1495  blg-0287 -26.493572
#
# [1496 rows x 61 columns]

# %%
features_df.loc[:, features_df.columns.difference(['event', 'umap_x', 'umap_y'])]
# Out:
#       amp_norm  amp_over_iqr  amp_over_std  autocorr_lag1  bg_flux_corr  \
# 0     0.992067     10.787576     12.507016       0.149561      0.034468
# 1     1.565392      8.542652      9.793618       0.214952      0.055667
# 2     2.000760      7.421014      8.195814       0.508820      0.065899
# 3     4.458237     46.856284     14.821213       0.933883      0.002544
# 4     7.459036     86.519269     15.747794       0.596577     -0.043535
# ...        ...           ...           ...            ...           ...
# 1491  4.329160     25.910809     18.763726       0.815771      0.015738
# 1492  6.008761     20.958060     17.535808       0.593907      0.257006
# 1493  3.721067     20.944929     14.661293       0.732331     -0.024077
# 1494  1.040138     12.557272     14.340447       0.203239     -0.099953
# 1495  3.376847     13.094697     16.530410       0.232762      0.132185
#
#       bg_flux_slope     bg_mean      bg_std  cadence_frac_large_gaps  \
# 0          0.000016  578.365288  180.502229                 0.240368
# 1          0.000057  411.100973  182.343757                 0.368357
# 2          0.000124  532.940209  165.865294                 0.247102
# 3          0.000005  412.123167  183.794338                 0.375524
# 4         -0.000110  413.415094  212.409338                 0.132492
# ...             ...         ...         ...                      ...
# 1491       0.000022  600.904471  191.351779                 0.261709
# 1492       0.000681  561.745984  170.148040                 0.263620
# 1493      -0.000038  538.329448  192.089416                 0.241971
# 1494      -0.000043  600.233055  181.937521                 0.239930
# 1495       0.000204  539.194645  165.563755                 0.258384
#
#       cadence_iqr  ...  seeing_mean  seeing_std  snr_median   snr_peak  \
# 0        0.063340  ...     5.584277    0.934971   16.964628  22.157882
# 1        0.814770  ...     5.274822    0.978471   10.340345  22.157882
# 2        0.090477  ...     5.450058    0.945527    7.336055  21.714724
# 3        0.823135  ...     5.274474    0.982689   20.106226  77.552586
# 4        1.977550  ...     5.853522    0.934506   10.541128  63.866836
# ...           ...  ...          ...         ...         ...        ...
# 1491     0.611930  ...     5.482395    0.982404   14.100470  47.205922
# 1492     0.625035  ...     5.186152    0.898601    6.349335  21.714724
# 1493     0.069725  ...     5.402028    0.997293   10.749863  33.929256
# 1494     0.064070  ...     5.500180    0.984070   21.714724  40.212452
# 1495     0.615300  ...     5.314383    0.904178    6.915517  22.157882
#
#       std_norm  std_over_mad  stetson_j  t_above_q25  t_above_q75  \
# 0     0.079321      1.728676   0.045913   3178.62416      1.13557
# 1     0.159838      1.746286   0.130544   3174.66809    111.89926
# 2     0.244120      1.813341   0.448160   3176.66933     15.13701
# 3     0.300801      6.350366   0.724446     49.83560     12.86662
# 4     0.473656     10.998238   0.701419      3.99978      0.00000
# ...        ...           ...        ...          ...          ...
# 1491  0.230720      2.738718   0.821444      8.16402      2.00426
# 1492  0.342657      2.413905   0.210889   2937.93808      1.02156
# 1493  0.253802      2.848224   0.491713    187.64300      5.02302
# 1494  0.072532      1.765042   0.107403   3171.63568      1.10634
# 1495  0.204281      1.589649   0.174571   3105.82369      2.01851
#
#       von_neumann_ratio
# 0              1.700827
# 1              1.569471
# 2              0.982286
# 3              0.132234
# 4              0.806794
# ...                 ...
# 1491           0.368429
# 1492           0.812114
# 1493           0.535224
# 1494           1.592388
# 1495           1.534473
#
# [1496 rows x 59 columns]

# %%
import hdbscan
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import RobustScaler

X = features_df.loc[:, features_df.columns.difference(['event', 'umap_x', 'umap_y'])]
selector = VarianceThreshold(threshold=1e-6)
X_reduced = selector.fit_transform(X)

scaler = RobustScaler()
X_scaled = scaler.fit_transform(X_reduced)

clusterer = hdbscan.HDBSCAN(
    min_cluster_size=100,     # try 25–50 to start
    min_samples=5,          # how conservative the cluster core is
    cluster_selection_epsilon=0.05,
    gen_min_span_tree=True
)

labels = clusterer.fit_predict(X_scaled)
features_df["cluster"] = labels
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/a356/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/a356/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
for c in sorted(np.unique(labels)):
    print(c, (labels == c).sum())

for idx, score in enumerate(clusterer.cluster_persistence_):
    print(f"Cluster {idx}: persistence={score:.3f}, size={(labels==idx).sum()}")
# Out:
# -1 97
# 0 222
# 1 224
# 2 793
# 3 160
# Cluster 0: persistence=0.164, size=222
# Cluster 1: persistence=0.038, size=224
# Cluster 2: persistence=0.466, size=793
# Cluster 3: persistence=0.371, size=160

# %%
from sklearn.metrics import silhouette_score
sil = silhouette_score(X_scaled, labels)
print(f"Silhouette: {sil:.5f}")
plt.hist(clusterer.probabilities_, bins=30)
plt.title("Cluster membership probability")
clusterer.cluster_persistence_
stable_clusters = np.where(clusterer.cluster_persistence_ > 0.35)[0]
for c in stable_clusters:
    print(c, (labels==c).sum())
features_df["cluster_stable"] = features_df["cluster"].apply(
    lambda c: c if c in stable_clusters else -1
)
# Out:
# Silhouette: 0.64248
# 2 793
# 3 160

# %%
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors

plt.figure(figsize=(8,6))
plt.scatter(
    features_df["umap_x"],
    features_df["umap_y"],
    c=features_df["cluster_stable"],
    # cmap="tab10",
    cmap=plt.cm.get_cmap('Accent', 8),
    # norm=mcolors.BoundaryNorm(np.arange(9), plt.cm.get_cmap('Accent', 8).N),
    s=20,
    alpha=0.8
)
plt.xlabel("UMAP 1")
plt.ylabel("UMAP 2")
plt.title("OGLE 2025 Microlensing Events - UMAP + HDBSCAN")
plt.colorbar(label="Cluster Label")
plt.show()
# Out:
# /var/folders/h8/b2hcw1rs5q902dzwq63hfyk40000gn/T/ipykernel_59954/1548462693.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap=plt.cm.get_cmap('Accent', 8),

# %%
features_df
# Out:
#       n_points    duration  cadence_med  cadence_std  cadence_iqr  \
# 0         4569  3178.62416     0.048045    13.452426     0.063340
# 1         2466  3174.66809     0.060230    18.426902     0.814770
# 2         4315  3177.66444     0.048150    13.858576     0.090477
# 3         2387  3174.66809     0.061825    18.742690     0.823135
# 4          318  3160.66304     1.956380    92.993883     1.977550
# ...        ...         ...          ...          ...          ...
# 1491      4250  3178.62717     0.048990    13.928394     0.611930
# 1492      3984  3178.62717     0.049980    14.463652     0.625035
# 1493      4547  3177.66442     0.047925    13.497520     0.069725
# 1494      4544  3178.62735     0.047980    13.493140     0.064070
# 1495      4146  3177.66444     0.049570    14.176442     0.615300
#
#       cadence_min  cadence_max  cadence_max_gap  cadence_frac_large_gaps  \
# 0         0.00213    872.77257        872.77257                 0.240368
# 1         0.00786    873.67026        873.67026                 0.368357
# 2         0.00464    872.77213        872.77213                 0.247102
# 3         0.00786    873.67026        873.67026                 0.375524
# 4         0.07517   1618.25929       1618.25929                 0.132492
# ...           ...          ...              ...                      ...
# 1491      0.00145    872.77258        872.77258                 0.261709
# 1492      0.00145    872.80925        872.80925                 0.263620
# 1493      0.00094    872.77216        872.77216                 0.241971
# 1494      0.00177    871.77393        871.77393                 0.239930
# 1495      0.00265    872.77213        872.77213                 0.258384
#
#       flux_mean  ...  seeing_flux_slope     bg_mean      bg_std  bg_flux_corr  \
# 0      1.077983  ...          -0.003921  578.365288  180.502229      0.034468
# 1      1.170225  ...           0.008202  411.100973  182.343757      0.055667
# 2      1.275117  ...           0.023373  532.940209  165.865294      0.065899
# 3      1.117995  ...           0.031831  412.123167  183.794338      0.002544
# 4      1.133161  ...           0.045375  413.415094  212.409338     -0.043535
# ...         ...  ...                ...         ...         ...           ...
# 1491   1.173951  ...          -0.016661  600.904471  191.351779      0.015738
# 1492   1.316572  ...           0.115378  561.745984  170.148040      0.257006
# 1493   1.188923  ...          -0.019645  538.329448  192.089416     -0.024077
# 1494   1.069662  ...          -0.011214  600.233055  181.937521     -0.099953
# 1495   1.253357  ...          -0.011233  539.194645  165.563755      0.132185
#
#       bg_flux_slope     event     umap_x     umap_y  cluster  cluster_stable
# 0          0.000016  blg-0491 -25.526321  34.209637        3               3
# 1          0.000057  blg-0801 -25.409752  35.322971        3               3
# 2          0.000124  blg-0490 -25.968149  35.862919        3               3
# 3          0.000005  blg-0800 -29.220160  37.385704        2               2
# 4         -0.000110  blg-0239 -31.654470  39.899464        1              -1
# ...             ...       ...        ...        ...      ...             ...
# 1491       0.000022  blg-0649 -28.215578  36.476910        2               2
# 1492       0.000681  blg-1228 -26.474440  37.406666        2               2
# 1493      -0.000038  blg-0286 -28.118980  36.375725        2               2
# 1494      -0.000043  blg-1229 -25.602663  33.960159        3               3
# 1495       0.000204  blg-0287 -26.493572  36.051182        2               2
#
# [1496 rows x 64 columns]

# %%
for c in sorted(features_df["cluster_stable"].unique()):
    sample = features_df.query("cluster_stable == @c").sample(min(3, len(features_df.query('cluster_stable == @c'))))
    print(f"\nCluster {c} → sample events:", list(sample["event"]))
# Out:
# Cluster -1 → sample events: ['blg-0811', 'blg-1472', 'blg-1456']
#
# Cluster 2 → sample events: ['blg-0660', 'blg-0501', 'blg-0884']
#
# Cluster 3 → sample events: ['blg-0857', 'blg-0984', 'blg-0434']

# %%
# -------------------------
# PSPL MODEL FUNCTION
# -------------------------
def pspl_model(t, t0, tE, u0, I0, fbl=1.0):
    """Compute PSPL microlensing model magnitudes."""
    u = np.sqrt(u0**2 + ((t - t0)/tE)**2)
    A = (u**2 + 2) / (u * np.sqrt(u**2 + 4))
    # Add blending: observed flux = fbl * A + (1 - fbl)
    F = fbl * A + (1 - fbl)
    m = I0 - 2.5 * np.log10(F)
    return m


# -------------------------
# PARAMS FILE PARSER
# -------------------------
def read_params_file(filepath):
    """Parse OGLE params.dat file into a dictionary."""
    params = {
        "event": os.path.basename(filepath).replace("_params.dat", "").lower(),
        "Field": None, "StarNo": None, "RA": None, "Dec": None, "Remarks": None,
    }

    with open(filepath, "r") as f:
        lines = [line.strip() for line in f if line.strip()]

    if lines:
        params["event_name"] = lines[0]

    for line in lines:
        if line.startswith("Field"):
            params["Field"] = line.split()[-1]
        elif line.startswith("StarNo"):
            params["StarNo"] = line.split()[-1]
        elif line.startswith("RA("):
            params["RA"] = line.split()[-1]
        elif line.startswith("Dec("):
            params["Dec"] = line.split()[-1]
        elif line.startswith("Remarks"):
            params["Remarks"] = " ".join(line.split()[1:]) if len(line.split()) > 1 else ""

    for line in lines:
        parts = line.split()
        if len(parts) == 3 and parts[0][0].isalpha():
            key, val, err = parts
            try:
                params[key] = float(val)
                params[key + "_err"] = float(err)
            except ValueError:
                pass

    return params


# -------------------------
# LOAD ALL PARAMS FILES
# -------------------------
param_dir = "data/raw/ogle4/2025/params"
param_files = sorted([
    os.path.join(param_dir, f) for f in os.listdir(param_dir)
    if f.endswith("_params.dat")
])

params_list = [read_params_file(f) for f in param_files]
params_df = pd.DataFrame(params_list)

# Normalize event name key
params_df["event"] = params_df["event"].str.lower()


# -------------------------
# PLOT LIGHT CURVES + MODEL BY CLUSTER
# -------------------------
for c in sorted(features_df["cluster_stable"].unique()):
    fig, axs = plt.subplots(1, 3, figsize=(15, 4), sharex=True, sharey=True)
    fig.suptitle(f"Cluster {c}", fontsize=14)

    sample = features_df.query("cluster == @c").sample(
        min(3, len(features_df.query('cluster == @c')))
    )

    for ax, event in zip(axs, sample["event"]):
        df = all_df[all_df["event"] == event]
        df = preprocess_lc(df)
        X, Y = df["HJD"].values, df["mag"].values

        # Fix: if HJD is relative (OGLE EWS gives HJD - 2450000)
        if X.mean() < 40000:
            X = X + 2450000

        # Focus around the event
        i = np.argmin(Y)  # minimum magnitude = peak
        half = 0.4 * (X.max() - X.min())
        mask = (X >= X[i] - half) & (X <= X[i] + half)
        Xc, Yc = X[mask], Y[mask]

        ax.errorbar(Xc, Yc, fmt=".", alpha=0.6, label="Data")

        # Try to get params
        ev = event.lower()
        try:
            p = params_df.loc[params_df["event"] == ev].iloc[0]
            t0 = p["Tmax"]
            tE = p["tau"]
            u0 = p["umin"]
            I0 = p.get("I0", np.median(Yc))  # fallback if missing
            fbl = p.get("fbl", 1.0)

            t_model = np.linspace(Xc.min(), Xc.max(), 500)
            m_model = pspl_model(t_model, t0, tE, u0, I0, fbl)
            ax.plot(t_model, m_model, "r-", lw=2, label="PSPL model")

            ax.text(
                0.02, 0.95, f"tE={tE:.1f}d\nu0={u0:.3f}\nI0={I0:.2f}\nRemarks={p['Remarks']}",
                transform=ax.transAxes, va="top", fontsize=8, color="darkred"
            )

        except Exception as e:
            print(f"⚠️ Skipped {event}: {e}")

        ax.invert_yaxis()
        ax.set_title(event)
        ax.legend(fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(10,6))
clusterer.condensed_tree_.plot(select_clusters=True, selection_palette='0.1')
plt.show()
