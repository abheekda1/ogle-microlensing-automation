# %%
import pandas as pd
import os
import sys
import glob
import numpy as np

sys.path.append(os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Test 1 CSV

# %%
df = pd.read_csv("data/raw/ogle4/2025/photometry/blg-0001_phot.dat",
                 sep='\\s+', names=["HJD", "mag", "err", 'unk1', 'unk2'])
df.head()
# Out:
#             HJD     mag    err  unk1   unk2
# 0  2.457822e+06  20.079  0.223  4.66   83.0
# 1  2.457823e+06  20.084  0.261  4.73  120.0
# 2  2.457827e+06  19.480  0.175  5.08  144.0
# 3  2.457828e+06  19.932  0.235  5.55  103.0
# 4  2.457829e+06  19.921  0.182  4.17  104.0

# %%
records = []
for path in glob.glob("data/raw/ogle4/2025/photometry/*.dat"):
    event = os.path.basename(path).split("_")[0]
    df = pd.read_csv(path, sep='\\s+', names=["HJD", "mag", "err", "unk1", "unk2"])
    df["event"] = event
    records.append(df)

all_df = pd.concat(records, ignore_index=True)
all_df.to_parquet("data/processed/ogle2025_lightcurves.parquet", compression="snappy", engine="fastparquet")
print("Saved", len(all_df), "rows.")
# Out:
# Saved 2565579 rows.

# %%
def preprocess_lc(df):
    df = df.sort_values("HJD").dropna()
    baseline = np.median(df["mag"].nlargest(int(len(df)*0.3)))
    df["flux"] = 10**(-0.4 * (df["mag"] - baseline))
    df["t_rel"] = df["HJD"] - df["HJD"].min()
    return df

# %%
from src.feature_extraction import extract_simple_features, extract_features
from tqdm import tqdm

features_simple = []
features = []
for event in tqdm(all_df["event"].unique(), desc="Extracting features"):
    df_event = all_df[all_df["event"] == event]
    df_event = preprocess_lc(df_event)
    feats_simple = extract_simple_features(df_event["t_rel"].values, df_event["flux"].values, df_event["err"].values)
    feats = extract_features(df_event["t_rel"].values, df_event["flux"].values, df_event["err"].values)
    feats_simple["event"] = event
    feats["event"] = event
    features_simple.append(feats_simple)
    features.append(feats)

features_simple_df = pd.DataFrame(features_simple).fillna(0)
features_simple_df.to_csv("data/features/features_ogle2025_simple.csv", index=False)
features_df = pd.DataFrame(features).fillna(0)
features_df.to_csv("data/features/features_ogle2025.csv", index=False)
# Out:
# Extracting features: 100%|██████████| 1496/1496 [01:28<00:00, 16.93it/s]

# %%
# len(pd.read_csv("data/features/features_ogle2025.csv").columns)
temp = features_df.iloc[:, :16]
temp['event'] = features_df['event']
features_df = temp
features_df
# Out:
#       n_points    duration  cadence_med  flux_mean  flux_std  flux_amp  \
# 0         4569  3178.62416     0.048045   1.077983  0.085507  1.069432
# 1         2466  3174.66809     0.060230   1.170225  0.187046  1.831861
# 2         4315  3177.66444     0.048150   1.275117  0.311281  2.551203
# 3         2387  3174.66809     0.061825   1.117995  0.336294  4.984287
# 4          318  3160.66304     1.956380   1.133161  0.536728  8.452286
# ...        ...         ...          ...        ...       ...       ...
# 1491      4250  3178.62717     0.048990   1.173951  0.270854  5.082222
# 1492      3984  3178.62717     0.049980   1.316572  0.451132  7.910968
# 1493      4547  3177.66442     0.047925   1.188923  0.301751  4.424064
# 1494      4544  3178.62735     0.047980   1.069662  0.077585  1.112597
# 1495      4146  3177.66444     0.049570   1.253357  0.256037  4.232396
#
#       flux_skew   flux_kurt  amp_norm  std_norm  flux_asym  rise_fall_ratio  \
# 0      0.811660    6.200264  0.992067  0.079321   0.018457        15.843277
# 1      1.002385    4.750533  1.565392  0.159838  -0.166192        20.614887
# 2      1.639576    5.564362  2.000760  0.244120  -0.285650        15.931352
# 3     10.040832  115.719071  4.458237  0.300801  -0.597205        27.336957
# 4     12.119374  168.126551  7.459036  0.473656  -0.096590        12.757479
# ...         ...         ...       ...       ...        ...              ...
# 1491   7.169236   83.335246  4.329160  0.230720   0.043050        18.296900
# 1492   6.454226   75.847788  6.008761  0.342657  -0.780413        42.104577
# 1493   5.640739   50.030392  3.721067  0.253802  -0.238922        14.368358
# 1494   0.878704    9.263032  1.040138  0.072532  -0.013918        36.844888
# 1495   1.654150   16.653908  3.376847  0.204281   0.105805        13.468094
#
#        fwhm_time  abbe_value  smoothness  outlier_frac     event
# 0     2356.39568    0.850413    0.063426      0.004377  blg-0491
# 1     3122.73629    0.784735    0.137076      0.009327  blg-0801
# 2     2710.69499    0.491143    0.221417      0.019467  blg-0490
# 3       18.99726    0.066117    0.100666      0.011730  blg-0800
# 4        0.00000    0.403397    0.119879      0.009434  blg-0239
# ...          ...         ...         ...           ...       ...
# 1491     3.02853    0.184215    0.138804      0.010588  blg-0649
# 1492     1.91649    0.406057    0.255381      0.008534  blg-1228
# 1493    18.11976    0.267612    0.156911      0.014295  blg-0286
# 1494  3090.70841    0.796194    0.056618      0.007482  blg-1229
# 1495     6.90636    0.767237    0.192721      0.004100  blg-0287
#
# [1496 rows x 17 columns]

# %%
from sklearn.preprocessing import StandardScaler

X = features_df.drop(columns=["event"], errors="ignore").fillna(0)
X_scaled = StandardScaler().fit_transform(X)

# %%
import umap

umap_model = umap.UMAP(
    n_neighbors=30,      # local neighborhood size
    min_dist=0.2,        # controls cluster tightness
    n_components=2,      # 2D embedding
    metric="euclidean",
    random_state=42
)

embedding = umap_model.fit_transform(X_scaled)
features_df["umap_x"] = embedding[:, 0]
features_df["umap_y"] = embedding[:, 1]

embedding
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/a356/lib/python3.13/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# array([[ 9.813824 ,  3.757451 ],
#        [ 9.611427 ,  3.5485923],
#        [ 9.844224 ,  2.6767216],
#        ...,
#        [-9.535295 ,  2.851124 ],
#        [ 9.639032 ,  3.6171231],
#        [-8.400495 ,  4.0672507]], shape=(1496, 2), dtype=float32)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(
    features_df["umap_x"], features_df["umap_y"],
    s=10, alpha=0.7, c="gray"
)
plt.title("UMAP embedding (unclustered)")
plt.xlabel("UMAP 1")
plt.ylabel("UMAP 2")
plt.show()

# %%
features_df.head()
for col in ["flux_skew", "fwhm_time", "duration"]:
    plt.figure(figsize=(7,5))
    plt.scatter(
        features_df["umap_x"], features_df["umap_y"],
        c=features_df[col], cmap="viridis", s=15
    )
    plt.title(f"UMAP colored by {col}")
    plt.xlabel("UMAP 1"); plt.ylabel("UMAP 2")
    plt.colorbar(label=col)
    plt.show()

# %%
features_df.iloc[:, :-1]
# Out:
#       n_points    duration  cadence_med  flux_mean  flux_std  flux_amp  \
# 0         4569  3178.62416     0.048045   1.077983  0.085507  1.069432
# 1         2466  3174.66809     0.060230   1.170225  0.187046  1.831861
# 2         4315  3177.66444     0.048150   1.275117  0.311281  2.551203
# 3         2387  3174.66809     0.061825   1.117995  0.336294  4.984287
# 4          318  3160.66304     1.956380   1.133161  0.536728  8.452286
# ...        ...         ...          ...        ...       ...       ...
# 1491      4250  3178.62717     0.048990   1.173951  0.270854  5.082222
# 1492      3984  3178.62717     0.049980   1.316572  0.451132  7.910968
# 1493      4547  3177.66442     0.047925   1.188923  0.301751  4.424064
# 1494      4544  3178.62735     0.047980   1.069662  0.077585  1.112597
# 1495      4146  3177.66444     0.049570   1.253357  0.256037  4.232396
#
#       flux_skew   flux_kurt  amp_norm  std_norm  flux_asym  rise_fall_ratio  \
# 0      0.811660    6.200264  0.992067  0.079321   0.018457        15.843277
# 1      1.002385    4.750533  1.565392  0.159838  -0.166192        20.614887
# 2      1.639576    5.564362  2.000760  0.244120  -0.285650        15.931352
# 3     10.040832  115.719071  4.458237  0.300801  -0.597205        27.336957
# 4     12.119374  168.126551  7.459036  0.473656  -0.096590        12.757479
# ...         ...         ...       ...       ...        ...              ...
# 1491   7.169236   83.335246  4.329160  0.230720   0.043050        18.296900
# 1492   6.454226   75.847788  6.008761  0.342657  -0.780413        42.104577
# 1493   5.640739   50.030392  3.721067  0.253802  -0.238922        14.368358
# 1494   0.878704    9.263032  1.040138  0.072532  -0.013918        36.844888
# 1495   1.654150   16.653908  3.376847  0.204281   0.105805        13.468094
#
#        fwhm_time  abbe_value  smoothness  outlier_frac     event     umap_x
# 0     2356.39568    0.850413    0.063426      0.004377  blg-0491   9.813824
# 1     3122.73629    0.784735    0.137076      0.009327  blg-0801   9.611427
# 2     2710.69499    0.491143    0.221417      0.019467  blg-0490   9.844224
# 3       18.99726    0.066117    0.100666      0.011730  blg-0800 -12.302144
# 4        0.00000    0.403397    0.119879      0.009434  blg-0239 -13.282426
# ...          ...         ...         ...           ...       ...        ...
# 1491     3.02853    0.184215    0.138804      0.010588  blg-0649 -10.256518
# 1492     1.91649    0.406057    0.255381      0.008534  blg-1228  -9.582838
# 1493    18.11976    0.267612    0.156911      0.014295  blg-0286  -9.535295
# 1494  3090.70841    0.796194    0.056618      0.007482  blg-1229   9.639032
# 1495     6.90636    0.767237    0.192721      0.004100  blg-0287  -8.400495
#
# [1496 rows x 18 columns]

# %%
import hdbscan

clusterer = hdbscan.HDBSCAN(
    min_cluster_size=50,     # try 25–50 to start
    min_samples=10,          # how conservative the cluster core is
    cluster_selection_epsilon=0.05,
    gen_min_span_tree=True
)

# labels = clusterer.fit_predict(embedding)
labels = clusterer.fit_predict(features_df.loc[:, features_df.columns.difference(['event', 'umap_x', 'umap_y'])])
features_df["cluster"] = labels
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/a356/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/a356/lib/python3.13/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score
sil = silhouette_score(X_scaled, labels)
print(f"Silhouette: {sil:.5f}")
plt.hist(clusterer.probabilities_, bins=30)
plt.title("Cluster membership probability")
clusterer.cluster_persistence_
stable_clusters = np.where(clusterer.cluster_persistence_ > 0.4)[0]
for c in stable_clusters:
    print(c, (labels==c).sum())
cluster0 = features_df[labels == 0]
cluster0.describe()
# Out:
# Silhouette: 0.09994
# 0 223
#          n_points    duration  cadence_med   flux_mean    flux_std  \
# count  223.000000  223.000000   223.000000  223.000000  223.000000
# mean   210.784753  976.050963     2.386219    1.194384    0.444448
# std     24.535474    9.304717     0.438035    0.230069    0.638977
# min     63.000000  875.784360     2.002130    1.008103    0.018569
# 25%    213.000000  972.683155     2.092615    1.054760    0.086900
# 50%    217.000000  978.639920     2.128620    1.120027    0.194015
# 75%    221.000000  979.635230     2.763830    1.255290    0.535923
# max    244.000000  987.657950     5.043330    3.013718    4.390758
#
#          flux_amp   flux_skew   flux_kurt    amp_norm    std_norm   flux_asym  \
# count  223.000000  223.000000  223.000000  223.000000  223.000000  223.000000
# mean     3.646021    3.989012   25.379535    2.642116    0.318579   -0.249359
# std      6.104858    2.518153   32.152598    3.890566    0.360122    0.393328
# min      0.130584    0.174715   -1.631046    0.128978    0.018313   -2.731037
# 25%      0.576561    2.130942    4.841119    0.535624    0.082173   -0.290226
# 50%      1.371277    3.251483   12.389203    1.208656    0.177175   -0.117244
# 75%      3.982555    5.251354   32.340494    2.975260    0.440919   -0.039803
# max     42.902465   12.587171  171.008251   31.417334    2.295791    0.038792
#
#        rise_fall_ratio   fwhm_time  abbe_value  smoothness  outlier_frac  \
# count       223.000000  223.000000  223.000000  223.000000    223.000000
# mean          6.725418   72.418955    0.179386    0.175228      0.030800
# std           6.658471  169.715201    0.141245    0.216910      0.014390
# min           0.000000    0.000000    0.003760    0.007451      0.000000
# 25%           3.475344    8.831780    0.068599    0.048051      0.020372
# 50%           4.496542   23.067370    0.159093    0.107315      0.031579
# 75%           7.799586   55.327580    0.245026    0.235681      0.040632
# max          39.923583  958.686390    0.923044    1.945973      0.069444
#
#            umap_x      umap_y  cluster
# count  223.000000  223.000000    223.0
# mean   -17.946093    1.325438      0.0
# std      0.633257    1.028245      0.0
# min    -19.323195   -0.062507      0.0
# 25%    -18.416239    0.535293      0.0
# 50%    -17.881464    1.017161      0.0
# 75%    -17.471537    2.030118      0.0
# max    -16.803991    3.855933      0.0

# %%
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors

plt.figure(figsize=(8,6))
plt.scatter(
    features_df["umap_x"],
    features_df["umap_y"],
    c=features_df["cluster"],
    # cmap="tab10",
    cmap=plt.cm.get_cmap('Accent', 8),
    # norm=mcolors.BoundaryNorm(np.arange(9), plt.cm.get_cmap('Accent', 8).N),
    s=20,
    alpha=0.8
)
plt.xlabel("UMAP 1")
plt.ylabel("UMAP 2")
plt.title("OGLE 2025 Microlensing Events - UMAP + HDBSCAN")
plt.colorbar(label="Cluster Label")
plt.show()
# Out:
# /var/folders/h8/b2hcw1rs5q902dzwq63hfyk40000gn/T/ipykernel_61873/280365842.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap=plt.cm.get_cmap('Accent', 8),

# %%
import numpy as np

for c in sorted(features_df["cluster"].unique()):
    sample = features_df.query("cluster == @c").sample(min(3, len(features_df.query('cluster == @c'))))
    print(f"\nCluster {c} → sample events:", list(sample["event"]))
# Out:
# Cluster -1 → sample events: ['blg-0329', 'blg-1139', 'blg-1080']
#
# Cluster 0 → sample events: ['blg-1329', 'blg-1287', 'blg-0412']
#
# Cluster 1 → sample events: ['blg-1033', 'blg-0299', 'blg-1280']
#
# Cluster 2 → sample events: ['blg-1362', 'blg-0774', 'blg-0928']
#
# Cluster 3 → sample events: ['blg-0382', 'blg-0518', 'blg-1060']
#
# Cluster 4 → sample events: ['blg-1115', 'blg-0101', 'blg-0657']
#
# Cluster 5 → sample events: ['blg-0351', 'blg-1490', 'blg-0120']
#
# Cluster 6 → sample events: ['blg-0883', 'blg-0952', 'blg-0314']

# %%
# -------------------------
# PSPL MODEL FUNCTION
# -------------------------
def pspl_model(t, t0, tE, u0, I0, fbl=1.0):
    """Compute PSPL microlensing model magnitudes."""
    u = np.sqrt(u0**2 + ((t - t0)/tE)**2)
    A = (u**2 + 2) / (u * np.sqrt(u**2 + 4))
    # Add blending: observed flux = fbl * A + (1 - fbl)
    F = fbl * A + (1 - fbl)
    m = I0 - 2.5 * np.log10(F)
    return m


# -------------------------
# PARAMS FILE PARSER
# -------------------------
def read_params_file(filepath):
    """Parse OGLE params.dat file into a dictionary."""
    params = {
        "event": os.path.basename(filepath).replace("_params.dat", "").lower(),
        "Field": None, "StarNo": None, "RA": None, "Dec": None, "Remarks": None,
    }

    with open(filepath, "r") as f:
        lines = [line.strip() for line in f if line.strip()]

    if lines:
        params["event_name"] = lines[0]

    for line in lines:
        if line.startswith("Field"):
            params["Field"] = line.split()[-1]
        elif line.startswith("StarNo"):
            params["StarNo"] = line.split()[-1]
        elif line.startswith("RA("):
            params["RA"] = line.split()[-1]
        elif line.startswith("Dec("):
            params["Dec"] = line.split()[-1]
        elif line.startswith("Remarks"):
            params["Remarks"] = " ".join(line.split()[1:]) if len(line.split()) > 1 else ""

    for line in lines:
        parts = line.split()
        if len(parts) == 3 and parts[0][0].isalpha():
            key, val, err = parts
            try:
                params[key] = float(val)
                params[key + "_err"] = float(err)
            except ValueError:
                pass

    return params


# -------------------------
# LOAD ALL PARAMS FILES
# -------------------------
param_dir = "data/raw/ogle4/2025/params"
param_files = sorted([
    os.path.join(param_dir, f) for f in os.listdir(param_dir)
    if f.endswith("_params.dat")
])

params_list = [read_params_file(f) for f in param_files]
params_df = pd.DataFrame(params_list)

# Normalize event name key
params_df["event"] = params_df["event"].str.lower()


# -------------------------
# PLOT LIGHT CURVES + MODEL BY CLUSTER
# -------------------------
for c in sorted(features_df["cluster"].unique()):
    fig, axs = plt.subplots(1, 3, figsize=(15, 4), sharex=True, sharey=True)
    fig.suptitle(f"Cluster {c}", fontsize=14)

    sample = features_df.query("cluster == @c").sample(
        min(3, len(features_df.query('cluster == @c')))
    )

    for ax, event in zip(axs, sample["event"]):
        df = all_df[all_df["event"] == event]
        df = preprocess_lc(df)
        X, Y = df["HJD"].values, df["mag"].values

        # Fix: if HJD is relative (OGLE EWS gives HJD - 2450000)
        if X.mean() < 40000:
            X = X + 2450000

        # Focus around the event
        i = np.argmin(Y)  # minimum magnitude = peak
        half = 0.4 * (X.max() - X.min())
        mask = (X >= X[i] - half) & (X <= X[i] + half)
        Xc, Yc = X[mask], Y[mask]

        ax.errorbar(Xc, Yc, fmt=".", alpha=0.6, label="Data")

        # Try to get params
        ev = event.lower()
        try:
            p = params_df.loc[params_df["event"] == ev].iloc[0]
            t0 = p["Tmax"]
            tE = p["tau"]
            u0 = p["umin"]
            I0 = p.get("I0", np.median(Yc))  # fallback if missing
            fbl = p.get("fbl", 1.0)

            t_model = np.linspace(Xc.min(), Xc.max(), 500)
            m_model = pspl_model(t_model, t0, tE, u0, I0, fbl)
            ax.plot(t_model, m_model, "r-", lw=2, label="PSPL model")

            ax.text(
                0.02, 0.95, f"tE={tE:.1f}d\nu0={u0:.3f}\nI0={I0:.2f}\nRemarks={p['Remarks']}",
                transform=ax.transAxes, va="top", fontsize=8, color="darkred"
            )

        except Exception as e:
            print(f"⚠️ Skipped {event}: {e}")

        ax.invert_yaxis()
        ax.set_title(event)
        ax.legend(fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
def pspl_model(t, t0, tE, u0, I0, fbl=1.0):
    """Compute PSPL microlensing model magnitudes."""
    u = np.sqrt(u0**2 + ((t - t0)/tE)**2)
    A = (u**2 + 2) / (u * np.sqrt(u**2 + 4))
    # Add blending: observed flux = fbl * A + (1 - fbl)
    F = fbl * A + (1 - fbl)
    m = I0 - 2.5 * np.log10(F)
    return m

def read_params_file(filepath):
    """Parse OGLE params.dat file into a dictionary."""
    params = {
        "event": os.path.basename(filepath).replace("_params.dat", "").lower(),
        "Field": None, "StarNo": None,
        "RA": None, "Dec": None, "Remarks": None
    }

    with open(filepath, "r") as f:
        lines = [line.strip() for line in f if line.strip()]

    # Extract event name (first non-empty line)
    if lines:
        params["event_name"] = lines[0]

    # Parse metadata lines (Field, RA, Dec)
    for line in lines:
        if line.startswith("Field"):
            params["Field"] = line.split()[-1]
        elif line.startswith("StarNo"):
            params["StarNo"] = line.split()[-1]
        elif line.startswith("RA("):
            params["RA"] = line.split()[-1]
        elif line.startswith("Dec("):
            params["Dec"] = line.split()[-1]
        elif line.startswith("Remarks"):
            params["Remarks"] = " ".join(line.split()[1:]) if len(line.split()) > 1 else ""

    # Extract numeric parameters (Tmax, tau, etc.)
    for line in lines:
        parts = line.split()
        if len(parts) == 3 and parts[0] not in ["Field", "StarNo", "Remarks"]:
            key, val, err = parts
            try:
                params[key] = float(val)
                params[key + "_err"] = float(err)
            except ValueError:
                pass

    return params

for c in sorted(features_df["cluster"].unique()):
    fig, axs = plt.subplots(1, 3, figsize=(15, 4))

    sample = features_df.query("cluster == @c").sample(
        min(3, len(features_df.query('cluster == @c')))
    )

    for ax, event in zip(axs, sample["event"]):
        df = all_df[all_df["event"] == event]
        df = preprocess_lc(df)
        X, Y = df["HJD"].values, df["mag"].values

        i = np.argmin(Y)  # brightest point
        half = 0.3 * (X.max() - X.min())
        mask = (X >= X[i] - half) & (X <= X[i] + half)
        Xc, Yc = X[mask], Y[mask]

        ax.errorbar(Xc, Yc, fmt=".", alpha=0.6, label="Data")

        # Match param file
        ev = event.lower()
        try:
            p = params_df[params_df["event"] == ev].iloc[0]
            t0, tE, u0, I0, fbl = p["Tmax"], p["tau"], p["umin"], p["I0"], p.get("fbl", 1.0)
            
            t_model = np.linspace(Xc.min(), Xc.max(), 400)
            m_model = pspl_model(t_model, t0, tE, u0, I0, fbl)
            ax.plot(t_model, m_model, "r-", lw=2, label="PSPL model")

            ax.text(0.02, 0.95, f"tE={tE:.1f}d\nu0={u0:.3f}", 
                    transform=ax.transAxes, va="top", fontsize=8, color="darkred")
        except Exception as e:
            print(f"⚠️ Skipped {event}: {e}")

        ax.invert_yaxis()
        ax.set_title(f"{event} (cluster {c})")
        ax.legend(fontsize=8)

    plt.tight_layout()
    plt.show()

# for c in sorted(features_df["cluster"].unique()):
#     fig, axs = plt.subplots(
#         nrows=1, ncols=3,
#         figsize=(15, 4),
#         # sharey=True,
#         # sharex=True
#     )

#     sample = features_df.query("cluster == @c").sample(min(3, len(features_df.query('cluster == @c'))))
#     for ax, event in zip(axs, sample["event"]):
#         df = all_df[all_df["event"] == event]
#         df = preprocess_lc(df)
#         X, Y = df["HJD"].values, df["mag"].values
#         # i = np.argmax(Y); w = int(0.1 * len(X))
#         # Xc, Yc = X[max(0, i - w): i + w + 1], Y[max(0, i - w): i + w + 1]
#         i = np.argmax(Y)
#         half = 0.3 * (X.max() - X.min())
#         mask = (X >= X[i] - half) & (X <= X[i] + half)
#         Xc, Yc = X[mask], Y[mask]
#         # ax.errorbar(Xc, Yc, yerr=df["err"], fmt=".", alpha=0.6)
#         ax.errorbar(Xc, Yc, fmt=".", alpha=0.6)
#         ax.invert_yaxis()
#         ax.set_title(f"{event} (cluster {c})")

# %%
df = pd.read_csv("data/raw/ogle4/2025/photometry/blg-0161_phot.dat",
                 sep='\\s+', names=["HJD", "mag", "err", 'unk1', 'unk2'])
# df = pd.read_table(f"data/raw/ogle4/2025/photometry/blg-0024_phot.dat",names=["HJD", "mag", "err", 'unk1', 'unk2'])
# df
plt.errorbar(df["HJD"], df["mag"], yerr=df["err"], fmt=".", alpha=0.6)
plt.gca().invert_yaxis()
plt.title(f"{event} (cluster {c})")
plt.show()
df
# Out:
#               HJD     mag    err  unk1    unk2
# 0    2.457798e+06  16.148  0.007  4.67  1012.0
# 1    2.457800e+06  16.157  0.007  5.17   674.0
# 2    2.457802e+06  16.169  0.007  5.20   705.0
# 3    2.457804e+06  16.145  0.007  4.65   926.0
# 4    2.457808e+06  16.164  0.006  5.31   424.0
# ..            ...     ...    ...   ...     ...
# 868  2.460943e+06  16.160  0.006  6.72   419.0
# 869  2.460951e+06  16.146  0.008  7.89   704.0
# 870  2.460955e+06  16.153  0.007  6.51   666.0
# 871  2.460958e+06  16.161  0.008  7.19   832.0
# 872  2.460968e+06  16.158  0.006  5.77   541.0
#
# [873 rows x 5 columns]
